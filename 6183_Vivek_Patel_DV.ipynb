# %% [markdown]
# **Importing NEcessary Libraries**

# %%
# Importing all necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Loading DATASET using pandas libary**

# %%
# Loading amazon dataset
df_data = pd.read_csv('amazon_data_200.csv')

# %% [markdown]
# **Print datasets Head and Tail**

# %%
df_data.head()
df_data.tail()
# Out:
#       product_category  product_sales  cost_price  selling_price  rating  \
# 1048  Home and Kitchen           1731         152            609     5.0
# 1049             Books           2377         419            580     3.9
# 1050             Books           1320         415            813     3.6
# 1051            Beauty           2077         981           1179     4.1
# 1052    Toys and Games           1187         726            970     4.6
#
#       discount
# 1048        64
# 1049        52
# 1050        29
# 1051        12
# 1052        13

# %% [markdown]
# **Data Manipulation**

# %%
# Printing Shape Dimensions
df_data.shape
# Out:
# (1053, 6)

# %%
# Descriptive summary
df_data.describe()
# Out:
#        product_sales   cost_price  selling_price       rating     discount
# count    1053.000000  1053.000000    1053.000000  1053.000000  1053.000000
# mean     1410.261159   494.365622     765.113960     3.042925    48.852802
# std       625.519037   289.982460     317.480316     1.130370    22.668888
# min       301.000000    10.000000      94.000000     1.000000    10.000000
# 25%       880.000000   245.000000     525.000000     2.100000    29.000000
# 50%      1396.000000   488.000000     762.000000     3.100000    49.000000
# 75%      1960.000000   751.000000    1011.000000     3.900000    67.000000
# max      2495.000000  1000.000000    1497.000000     5.000000    90.000000

# %%
# Checking null values

df_data.isnull().sum()
# Out:
# product_category    0
# product_sales       0
# cost_price          0
# selling_price       0
# rating              0
# discount            0
# dtype: int64

# %%
# Complete Columns Information about dataset
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1053 entries, 0 to 1052
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_category  1053 non-null   object
#  1   product_sales     1053 non-null   int64
#  2   cost_price        1053 non-null   int64
#  3   selling_price     1053 non-null   int64
#  4   rating            1053 non-null   float64
#  5   discount          1053 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 49.5+ KB

# %%
df_data.columns
# Out:
# Index(['product_category', 'product_sales', 'cost_price', 'selling_price',
#        'rating', 'discount'],
#       dtype='object')

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.nunique()
# Out:
# product_category     10
# product_sales       857
# cost_price          669
# selling_price       695
# rating               41
# discount             81
# dtype: int64

# %%
df_data['product_category'].value_counts()
# Out:
# Beauty                 113
# Furniture              112
# Clothing               112
# Grocery                110
# Home and Kitchen       108
# Sports and Outdoors    106
# Electronics             99
# Books                   98
# Toys and Games          98
# Automotive              97
# Name: product_category, dtype: int64

# %%
df_data.discount.value_counts()
# Out:
# 34    22
# 62    21
# 43    21
# 51    21
# 89    19
#       ..
# 85     8
# 74     8
# 90     8
# 36     6
# 78     6
# Name: discount, Length: 81, dtype: int64

# %%
df_data.rating.value_counts()
# Out:
# 3.2    44
# 2.5    38
# 4.5    37
# 3.4    35
# 4.8    34
# 1.9    33
# 3.5    32
# 1.7    30
# 2.7    30
# 3.7    30
# 3.1    30
# 3.6    30
# 2.0    30
# 4.7    28
# 2.8    28
# 3.0    27
# 2.4    27
# 1.3    26
# 1.8    26
# 3.9    26
# 1.6    24
# 4.9    24
# 4.3    24
# 2.6    24
# 3.8    24
# 2.2    24
# 1.2    23
# 4.1    23
# 4.6    23
# 1.4    23
# 1.5    22
# 2.9    21
# 3.3    21
# 4.4    19
# 2.1    19
# 5.0    19
# 2.3    18
# 4.0    16
# 1.1    16
# 4.2    15
# 1.0    10
# Name: rating, dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1053 entries, 0 to 1052
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_category  1053 non-null   object
#  1   product_sales     1053 non-null   int64
#  2   cost_price        1053 non-null   int64
#  3   selling_price     1053 non-null   int64
#  4   rating            1053 non-null   float64
#  5   discount          1053 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 49.5+ KB

# %%
df_data.drop_duplicates(subset=None,keep='first',inplace=True)
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1053 entries, 0 to 1052
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_category  1053 non-null   object
#  1   product_sales     1053 non-null   int64
#  2   cost_price        1053 non-null   int64
#  3   selling_price     1053 non-null   int64
#  4   rating            1053 non-null   float64
#  5   discount          1053 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 57.6+ KB

# %%
1050-987
# Out:
# 63

# %%
df_data['product_category'].value_counts()
# Out:
# Beauty                 113
# Furniture              112
# Clothing               112
# Grocery                110
# Home and Kitchen       108
# Sports and Outdoors    106
# Electronics             99
# Books                   98
# Toys and Games          98
# Automotive              97
# Name: product_category, dtype: int64

# %%
df_data['product_sales'].value_counts()
# Out:
# 858     4
# 1733    3
# 512     3
# 783     3
# 1529    3
#        ..
# 928     1
# 2303    1
# 407     1
# 508     1
# 1187    1
# Name: product_sales, Length: 857, dtype: int64

# %% [markdown]
# **Performing statistical analysis**

# %%
selling_price_data=df_data['selling_price']
# Descriptive statistics
mean = selling_price.mean()
median = selling_price.median()
mode = selling_price.mode()[0]
std_dev = selling_price.std()

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 765.1139601139602
# Median: 762.0
# Mode: 383
# Standard Deviation: 317.48031633363127

# %%
variance = df_data.var()
print("Variance:")
print(variance)

# Calculate the covariance matrix
covariance_matrix = df_data.cov()
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Variance:
# product_sales    391274.065762
# cost_price        84089.827220
# selling_price    100793.751259
# rating                1.277737
# discount            513.878502
# dtype: float64
#
# Covariance Matrix:
#                product_sales    cost_price  selling_price     rating  \
# product_sales  391274.065762  -4220.779987   -4130.401463   3.703513
# cost_price      -4220.779987  84089.827220   84070.743465  15.220983
# selling_price   -4130.401463  84070.743465  100793.751259  17.309742
# rating              3.703513     15.220983      17.309742   1.277737
# discount          -20.781864   -162.872936    -106.949939  -0.392440
#
#                  discount
# product_sales  -20.781864
# cost_price    -162.872936
# selling_price -106.949939
# rating          -0.392440
# discount       513.878502
# ...

# %%
df_data.corr()
# Out:
# <ipython-input-7-c9299cbceaaa>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_data.corr()
#                product_sales  cost_price  selling_price    rating  discount
# product_sales       1.000000   -0.023269      -0.020799  0.005238 -0.001466
# cost_price         -0.023269    1.000000       0.913180  0.046436 -0.024777
# selling_price      -0.020799    0.913180       1.000000  0.048234 -0.014861
# rating              0.005238    0.046436       0.048234  1.000000 -0.015315
# discount           -0.001466   -0.024777      -0.014861 -0.015315  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...

# %% [markdown]
# Conclusion :
# Descriptive Statistics:
#
# Mean: The average score in selling_price is approximately **765.1139601139602**.
#
# Median: The middle value (50th percentile) of the selling price is approximately **762**
#
# Mode: The most frequently occurring selling price is 383.
#
# Standard Deviation: The standard deviation of the selling price is approximately **317.48031633363127**, indicating a high amount of variability.

# %% [markdown]
# # **Univariate Analysis**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=selling_price, color='darkblue')
plt.title("Selling Price Count Plot")
plt.xlabel("Selling Price")
plt.ylabel("Count")
plt.show()


plt.figure(figsize=(10, 6))
plt.hist(selling_price, bins=5, color='pink', edgecolor='black')
plt.title("selling Price")
plt.show()

# %% [markdown]
# # **Count Plot:**
#
# The count plot of selling price does not provides a clear visualization of selling price for each product because of high variation in data and length of data
#
# # **Histogram:**
#
# The histogram ofselling price shows that the majority of products price's are concentrated around the middle range (400 to 1200). There are 5 bins in the histogram, indicating that the prices are divided into five intervals.

# %%
sns.countplot(x=df_data['product_category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Product Category Count plot**
#
#
# The line plot effectively illustrates the product distribution within each category by using color-coded bars.
# Also we can conclude that every category has a range of 85-110 products with in it

# %%
plt.figure(figsize=(15,12))
df_data['product_category'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # **Product Category Pie Chart**
#
# The pie chart effectively illustrates the product distribution within each category by using color-coded segments.
# Also we can conclude that every category has a 10% out of 100% products with in it

# %%
sns.countplot(x = 'rating',data = df_data, palette = 'rainbow')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Count Plot for rating products**
# The rating count chart reveals the distribution of product ratings. Most products have ratings clustered around the mid-range, with a few exceptional products receiving higher ratings.

# %%
x=df_data['product_sales'].head(25)
plt.figure(figsize=(15,12))
sns.countplot(x=x,data=df_data,palette='rocket_r',order=x.value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Product sales count chart**
# The product sales count chart provides a clear overview of the distribution of products among different categories. This information can be valuable for inventory management and product strategy decisions.

# %%
df_data.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# # **Histogram for all coloumns in my dataset**
#
# This helps in visualization all coloumns individually and provides a great insights

# %% [markdown]
# # **Bivariate Analysis**
#
# ---

# %%
fig,ax=plt.subplots(figsize=(8,12))
ax.scatter(df_data['cost_price'],df_data['selling_price'])
ax.set_xlabel('Cost Price')
ax.set_ylabel('Selling Price')
plt.show()

# %% [markdown]
# # **Scatter Plot**
# The scatterplot illustrates the relationship between cost price and selling price for the products in the dataset. It reveals that there is a generally positive correlation between the two variables, suggesting that as the cost price increases, the selling price tends to increase as well. However, there are some data points that deviate from this trend, indicating potential variations in pricing strategies or product characteristics. Further analysis may be necessary to understand these outliers and their impact on pricing decisions.

# %%
x=df_data['selling_price'].head(10)
y=df_data['discount'].head(10)
sns.lineplot(x=x,y=y,label='Selling Price',data=df_data)
plt.legend()
plt.show()

# %% [markdown]
# # **Line Plot between selling price and discount**
# The line plot displays the relationship between selling price and the corresponding discounts for the top 10 products in the dataset. It suggests that as the selling price increases, there is a tendency for discounts to decrease. This visualization provides insights into the pricing strategy employed for these products, showing that higher-priced items often have lower discounts applied.

# %%
x=df_data['cost_price'].head(20)
y=df_data['selling_price'].head(20)
sns.lineplot(x=x,y=y,label='Selling VS Cost',data=df_data)
plt.legend()
plt.show()

# %% [markdown]
# # **Line plot between cost vs selling price**
# The line plot compares the cost price to the selling price for the first 20 products in the dataset. It demonstrates the pricing relationship for these products, revealing that in most cases, the selling price is higher than the cost price. This suggests that, on average, the products are sold at a profit. However, there are instances where the selling price is close to or lower than the cost price, which may warrant further examination to understand the profitability of those specific products.

# %%
df_data.groupby('product_category')[['selling_price','product_sales']].sum().plot.bar(color=['pink','blue'],figsize=(8,5))
plt.ylabel('Product Category and selling price/sales')
plt.show()

# %% [markdown]
# # **Bar plot between Category and product selling and cost price**
# The grouped bar chart provides a visual representation of the total selling price and product sales for each product category. It highlights that Category D has the highest cumulative selling price and product sales, while Category B has the lowest. This information is valuable for assessing the overall performance of product categories in terms of revenue generation. Additionally, it can aid in identifying which categories contribute the most to sales and revenue, helping to make informed business decisions related to product management and marketing strategies.

# %% [markdown]
# # **Multivariate Analysis**

# %%
sns.pairplot(df_data, hue = 'product_category')

# %% [markdown]
# # **Pair plot**
# The pair plot with hue differentiation by product category offers a comprehensive view of the relationships between different pairs of variables in the dataset. Each scatterplot in the pair plot shows the correlation and distribution of variables, with distinct colors representing different product categories.
#
# From the pair plot, we can make the following observations:
#
# 1. **Product Sales vs. Selling Price**: There appears to be a positive correlation between product sales and selling price, indicating that higher-priced products tend to have higher sales.
#
# 2. **Product Sales vs. Cost Price**: There is a similar positive correlation between product sales and cost price, suggesting that products with higher costs also tend to have higher sales.
#
# 3. **Product Sales vs. Rating**: The relationship between product sales and rating is less clear, with no obvious linear correlation. However, some product categories may show distinct patterns.
#
# 4. **Product Sales vs. Discount**: The relationship between product sales and discount also varies, with some categories exhibiting different trends.
#
# 5. **Selling Price vs. Cost Price**: The scatterplots for selling price vs. cost price show the pricing structure for different product categories. Some categories tend to have higher markups, while others have lower markups.
#
# Overall, the pair plot with hue differentiation helps us understand how different variables are related and how these relationships may vary across different product categories. It's a valuable tool for exploring the dataset and identifying potential insights for further analysis.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample data for the five examples
data1 = {
    'product_sales': df_data['product_sales'],
    'cost_price': df_data['cost_price'],
    'selling_price': df_data['selling_price'],
}

data2 = {
    'selling_price': df_data['selling_price'],
    'discount': df_data['discount'],
}

data3 = {
    'cost_price': df_data['cost_price'],
    'selling_price': df_data['selling_price'],
}


data4 = {
    'selling_price': df_data['selling_price'],
    'product_sales': df_data['product_sales'],
}

# Create DataFrames for each dataset
df_data1 = pd.DataFrame(data1)
df_data2 = pd.DataFrame(data2)
df_data3 = pd.DataFrame(data3)
df_data4 = pd.DataFrame(data4)


# Create pair plots for each dataset
sns.pairplot(df_data1)
plt.suptitle('Product vs Cost price vs selling price')
plt.show()

sns.pairplot(df_data2)
plt.suptitle('Selling price vs discount')
plt.show()

sns.pairplot(df_data3)
plt.suptitle('Cost price vs selling price')
plt.show()

sns.pairplot(df_data4)
plt.suptitle('selling price vs product sales')
plt.show()

# %% [markdown]
# # **Different PairPlots**
# The pair plots provide visual insights into the relationships between various pairs of variables within the dataset. Here are the conclusions for each pair plot:
#
# 1. **Product vs. Cost Price vs. Selling Price**:
#    - The pair plot demonstrates the relationships between product sales, cost price, and selling price.
#    - It shows that there is a positive correlation between product sales and selling price, suggesting that products with higher selling prices tend to have higher sales.
#    - Additionally, there is a similar positive correlation between product sales and cost price, indicating that products with higher costs can also lead to higher sales.
#
# 2. **Selling Price vs. Discount**:
#    - This pair plot visualizes the relationship between selling price and discounts.
#    - It indicates that there may be a negative correlation between selling price and discounts, meaning that products with higher prices tend to have lower discounts applied.
#
# 3. **Cost Price vs. Selling Price**:
#    - The pair plot for cost price and selling price highlights their relationship.
#    - It suggests that there is generally a positive correlation between these two variables, which is expected since selling prices are often set above cost prices to ensure a profit margin.
#
# 4. **Selling Price vs. Product Sales**:
#    - This pair plot explores the connection between selling price and product sales.
#    - It reveals a positive correlation, suggesting that products with higher selling prices tend to achieve higher sales figures.
#
# These pair plots are valuable tools for understanding how different variables within the dataset relate to one another. They provide insights into potential patterns and correlations, which can inform decision-making processes related to pricing, sales strategies, and cost management.

# %%
corr = df_data.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
# Out:
# <ipython-input-21-c27c71320d5f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_data.corr()
# <Axes: >

# %% [markdown]
# A heatmap is a graphical representation of data in a matrix format, where values are represented by different colors. It is particularly useful for visualizing relationships and patterns in complex datasets. In the context of a correlation matrix heatmap:
#
# 1. **Color Gradient**:
#    - The heatmap uses a color gradient to represent the values in the matrix. Typically, a gradient of colors ranging from cool (e.g., blue) to warm (e.g., red) is used.
#    - In a correlation matrix, cooler colors (shades of blue) represent lower or negative correlations, while warmer colors (shades of red) represent higher or positive correlations.
#
# 2. **Correlation Values**:
#    - Each cell in the matrix represents the correlation coefficient between two variables. This value ranges from -1 to 1, where:
#      - 1 indicates a perfect positive correlation (as one variable increases, the other also increases proportionally).
#      - -1 indicates a perfect negative correlation (as one variable increases, the other decreases proportionally).
#      - 0 indicates no linear correlation between the variables.
#
# 3. **Annotations**:
#    - Annotations are usually included within each cell to display the exact correlation coefficient. These values provide quantitative information about the strength and direction of the relationship.
#
# 4. **Diagonal Line**:
#    - The diagonal line in the heatmap (from top-left to bottom-right) represents the correlation of each variable with itself, which is always 1.
#
# 5. **Interpretation**:
#    - A positive correlation (closer to 1) between two variables suggests that they tend to increase or decrease together. For example, if one subject's score increases, the other subject's score is also likely to increase.
#
#    - A negative correlation (closer to -1) suggests an inverse relationship. As one variable increases, the other tends to decrease.
#
#    - A correlation close to 0 indicates a weak or no linear relationship between the variables.
#
#    - A correlation of 1 or -1 indicates a perfect linear relationship.
#
#    - The strength and direction of correlation can be useful in understanding how variables interact with each other.
#
# Remember, correlation does not imply causation. Even if two variables are highly correlated, it doesn't necessarily mean that one causes the other to change. Other factors may be involved.
#
# In summary, a heatmap of a correlation matrix helps to visually identify relationships and patterns in a dataset, making it a valuable tool for exploratory data analysis.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='cost_price', y='product_sales',hue="product_category", data=df_data, color='skyblue')
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # **Scatter plot of category**
# The scatterplot provides a visual representation of the relationship between cost price and product sales, with each data point color-coded by product category. Here is the conclusion for this scatterplot:
#
# - The scatterplot reveals how product sales relate to cost price within different product categories.
# - It shows that while there is a general positive trend indicating that higher-cost products tend to have higher sales, there is also variation within each category.
# - The color-coding by product category allows for a clear distinction between different categories, highlighting potential differences in pricing and sales strategies.
# - This visualization can assist in identifying which product categories are more price-sensitive or where pricing strategies may need adjustment to optimize sales and profitability.
#
# In summary, the scatterplot provides valuable insights into the relationship between cost price, product sales, and product categories, helping to inform pricing and sales strategies.

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(x='cost_price', y='product_sales',hue="product_category", data=df_data, color='skyblue')
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:skyblue'` for same effect.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # **SwarmPlot of category**
# The swarmplot provides a detailed view of the relationship between cost price and product sales while also considering product categories through color-coding. Here's the conclusion for this swarmplot:
#
# - The swarmplot offers a fine-grained representation of how product sales are distributed concerning cost price within different product categories.
# - Each data point represents a product and is positioned based on its cost price and product sales.
# - The color-coded categories allow for a clear distinction between different product categories within the plot.
# - Observations from the swarmplot include:
#   - In some categories, there are products with low cost prices that still achieve high sales.
#   - Certain categories have a wide range of cost prices and sales, indicating potential variations in product strategies.
#   - The plot provides insights into individual data points, making it useful for identifying outliers and specific products with exceptional performance.
#
# In summary, the swarmplot is a valuable tool for exploring the distribution of product sales concerning cost price, with the added dimension of product categories. It can help identify patterns and outliers that may inform pricing and product management decisions.
